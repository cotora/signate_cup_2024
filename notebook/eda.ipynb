# %%
import sys
sys.path.append('..')

# %%
import preprocess as pp
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('../data/input/train.csv')
test_data = pd.read_csv('../data/input/test.csv')

# %%
train_data=pp.preprocess(train_data)

# %%
train_data["OnePersonMoney"]=train_data["MonthlyIncome"]/train_data["NumberOfPersonVisiting"]

# %%
train_data["ChildRatio"]=train_data["ChildNum"]/train_data["NumberOfPersonVisiting"]

# %%
train_data.groupby("ProdTaken")["ChildRatio"].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='ProdTaken'>

# %%
train_data.groupby("TypeofContact")["ProdTaken"].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeofContact'>

# %%
train_data["NumberOfTrips"].unique()
test_data["NumberOfTrips"].unique()
# Out:
# array(['7', '4', '1', '年に6回', '5', '3', '2', '年に4回', '年に1回', '6', '年に2回',
#        '年に3回', '年に5回', '年に7回', nan, '半年に1回', '四半期に1回', '年に8回', '8'],
#       dtype=object)

# %%
train_data["TypeofContact"].value_counts()
# Out:
# TypeofContact
# Self Enquiry       2194
# Company Invited    1289
# Name: count, dtype: int64

# %%
train_data = pp.preprocess(train_data)
test_data = pp.preprocess(test_data)

# %%
train_data.columns
# Out:
# Index(['id', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'NumberOfTrips', 'Passport',
#        'PitchSatisfactionScore', 'Designation', 'MonthlyIncome', 'ProdTaken',
#        'MarriageStatus', 'CarOwnership', 'ChildNum'],
#       dtype='object')

# %%
train_data["Designation"].value_counts()
# Out:
# Designation
# executive        1140
# manager          1040
# seniormanager     847
# avp               301
# vp                119
# μanager            15
# еxecutive          10
# аvp                 7
# αvp                 3
# ѕeniormanager       3
# տeniormanager       2
# seniorμanager       1
# տeniorμanager       1
# Name: count, dtype: int64

# %%
train_data.columns
# Out:
# Index(['id', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'PreferredPropertyStar', 'Passport',
#        'PitchSatisfactionScore', 'MonthlyIncome', 'ProdTaken', 'ChildNum',
#        'TypeofContact_Company Invited', 'TypeofContact_Self Enquiry',
#        'Occupation_Large Business', 'Occupation_Salaried',
#        'Occupation_Small Business', 'Gender_female', 'Gender_male',
#        'ProductPitched_basic', 'ProductPitched_deluxe', 'ProductPitched_king',
#        'ProductPitched_standard', 'ProductPitched_superdeluxe',
#        'NumberOfTrips_1', 'NumberOfTrips_2', 'NumberOfTrips_3',
#        'NumberOfTrips_4', 'NumberOfTrips_5', 'NumberOfTrips_6',
#        'NumberOfTrips_7', 'NumberOfTrips_8', 'NumberOfTrips_半年に1回',
#        'NumberOfTrips_四半期に1回', 'NumberOfTrips_年に1回', 'NumberOfTrips_年に2回',
#        'NumberOfTrips_年に3回', 'NumberOfTrips_年に4回', 'NumberOfTrips_年に5回',
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(train_data['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.boxplot([train_data[train_data['ProdTaken'] == 0]['Age'],
             train_data[train_data['ProdTaken'] == 1]['Age']])
plt.xticks([1, 2], ['Not Taken', 'Taken'])
plt.xlabel('ProdTaken')
plt.ylabel('Age')
plt.title('Boxplot of Age by ProdTaken')
plt.show()

# %%
train_data.columns
# Out:
# Index(['id', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'PreferredPropertyStar', 'Passport',
#        'PitchSatisfactionScore', 'MonthlyIncome', 'ProdTaken', 'ChildNum',
#        'TypeofContact_Company Invited', 'TypeofContact_Self Enquiry',
#        'Occupation_Large Business', 'Occupation_Salaried',
#        'Occupation_Small Business', 'Gender_female', 'Gender_male',
#        'ProductPitched_basic', 'ProductPitched_deluxe', 'ProductPitched_king',
#        'ProductPitched_standard', 'ProductPitched_superdeluxe',
#        'NumberOfTrips_1', 'NumberOfTrips_2', 'NumberOfTrips_3',
#        'NumberOfTrips_4', 'NumberOfTrips_5', 'NumberOfTrips_6',
#        'NumberOfTrips_7', 'NumberOfTrips_8', 'NumberOfTrips_半年に1回',
#        'NumberOfTrips_四半期に1回', 'NumberOfTrips_年に1回', 'NumberOfTrips_年に2回',
#        'NumberOfTrips_年に3回', 'NumberOfTrips_年に4回', 'NumberOfTrips_年に5回',
# ...
